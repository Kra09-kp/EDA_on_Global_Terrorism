# %% [markdown]
# #  Exploratory Data Analysis on Global terriorism

# %% [markdown]
# ## Import necessaray modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
pd.set_option('display.max_columns',None) #to view all columns

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
pd.set_option('display.max_rows',None) #to view all rows

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.dtypes
# Out:
# eventid                 int64
# iyear                   int64
# imonth                  int64
# iday                    int64
# approxdate             object
# extended                int64
# resolution             object
# country                 int64
# country_txt            object
# region                  int64
# region_txt             object
# provstate              object
# city                   object
# latitude              float64
# longitude             float64
# specificity           float64
# vicinity                int64
# location               object
# summary                object
# crit1                   int64
# crit2                   int64
# crit3                   int64
# doubtterr             float64
# alternative           float64
# alternative_txt        object
# multiple              float64
# success                 int64
# suicide                 int64
# attacktype1             int64
# attacktype1_txt        object
# attacktype2           float64
# ...

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# gsubname3             181671
# weapsubtype4_txt      181621
# weapsubtype4          181621
# weaptype4             181618
# weaptype4_txt         181618
# claimmode3            181558
# claimmode3_txt        181558
# gsubname2             181531
# claim3                181373
# guncertain3           181371
# gname3                181367
# divert                181367
# attacktype3           181263
# attacktype3_txt       181263
# ransomnote            181177
# ransompaidus          181139
# ransomamtus           181128
# claimmode2            181075
# claimmode2_txt        181075
# ransompaid            180917
# corp3                 180665
# targsubtype3          180594
# targsubtype3_txt      180594
# natlty3_txt           180544
# natlty3               180544
# target3               180516
# targtype3             180515
# targtype3_txt         180515
# ransomamt             180341
# weapsubtype3_txt      179998
# weapsubtype3          179998
# weaptype3_txt         179828
# ...

# %%
data.corr()
# Out:
#                  eventid     iyear    imonth      iday  extended   country  \
# eventid         1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear           0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth          0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday            0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended        0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# country        -0.135039 -0.135023 -0.006305  0.003468 -0.020466  1.000000
# region          0.401371  0.401384 -0.002999  0.009710  0.038389  0.148597
# latitude        0.166886  0.166933 -0.015978  0.003423 -0.024749  0.178567
# longitude       0.003907  0.003917 -0.003880 -0.002285  0.000523 -0.000269
# specificity     0.030641  0.030626  0.003621 -0.006991  0.057897 -0.084599
# vicinity        0.070646  0.070659 -0.004501 -0.005367  0.017784 -0.012291
# ...

# %% [markdown]
# ## Data Cleaning and Exploration

# %%
t_data = data[['eventid','iyear', 'imonth', 'iday', 'country_txt','city','provstate','region_txt','attacktype1_txt','weaptype1_txt','targtype1_txt','gname','targsubtype1_txt','success','nkill']]

# %%
t_data.rename(columns={'eventid':"Id",'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','city':'City','provstate':'State','region_txt':'Region','attacktype1_txt':'Attacktype','weaptype1_txt':'Weapontype','targtype1_txt':'Targettype','gname':'Group','targsubtype1_txt':'Targetsubtype','success':'Success','nkill':'Killed'},inplace=True)
t_data.head()
# Out:
#              Id  Year  Month  Day             Country           City    State  \
# 0  197000000001  1970      7    2  Dominican Republic  Santo Domingo      NaN
# 1  197000000002  1970      0    0              Mexico    Mexico city  Federal
# 2  197001000001  1970      1    0         Philippines        Unknown   Tarlac
# 3  197001000002  1970      1    0              Greece         Athens   Attica
# 4  197001000003  1970      1    0               Japan        Fukouka  Fukouka
#
#                         Region                      Attacktype  Weapontype  \
# 0  Central America & Caribbean                   Assassination     Unknown
# 1                North America     Hostage Taking (Kidnapping)     Unknown
# 2               Southeast Asia                   Assassination     Unknown
# 3               Western Europe               Bombing/Explosion  Explosives
# 4                    East Asia  Facility/Infrastructure Attack  Incendiary
#
# ...

# %%
t_data.describe()
# Out:
#                  Id           Year          Month            Day  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#              Success         Killed
# count  181691.000000  171378.000000
# mean        0.889598       2.403272
# std         0.313391      11.545741
# min         0.000000       0.000000
# 25%         1.000000       0.000000
# 50%         1.000000       0.000000
# 75%         1.000000       2.000000
# max         1.000000    1570.000000

# %%
t_data.shape
# Out:
# (181691, 15)

# %%
t_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Id             181691 non-null  int64
#  1   Year           181691 non-null  int64
#  2   Month          181691 non-null  int64
#  3   Day            181691 non-null  int64
#  4   Country        181691 non-null  object
#  5   City           181257 non-null  object
#  6   State          181270 non-null  object
#  7   Region         181691 non-null  object
#  8   Attacktype     181691 non-null  object
#  9   Weapontype     181691 non-null  object
#  10  Targettype     181691 non-null  object
#  11  Group          181691 non-null  object
#  12  Targetsubtype  171318 non-null  object
#  13  Success        181691 non-null  int64
#  14  Killed         171378 non-null  float64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 20.8+ MB

# %%
t_data.isnull().sum().sort_values(ascending=False)
# Out:
# Targetsubtype    10373
# Killed           10313
# City               434
# State              421
# Id                   0
# Year                 0
# Month                0
# Day                  0
# Country              0
# Region               0
# Attacktype           0
# Weapontype           0
# Targettype           0
# Group                0
# Success              0
# dtype: int64

# %%
t_data.dtypes
# Out:
# Id                 int64
# Year               int64
# Month              int64
# Day                int64
# Country           object
# City              object
# State             object
# Region            object
# Attacktype        object
# Weapontype        object
# Targettype        object
# Group             object
# Targetsubtype     object
# Success            int64
# Killed           float64
# dtype: object

# %%
t_data['Targetsubtype'].fillna("Others",inplace=True)
t_data['City'].fillna("Unknown",inplace=True)
t_data['State'].fillna("Unknown",inplace=True)
t_data['Killed'].fillna(0,inplace=True)
t_data.head()
# Out:
#              Id  Year  Month  Day             Country           City    State  \
# 0  197000000001  1970      7    2  Dominican Republic  Santo Domingo  Unknown
# 1  197000000002  1970      0    0              Mexico    Mexico city  Federal
# 2  197001000001  1970      1    0         Philippines        Unknown   Tarlac
# 3  197001000002  1970      1    0              Greece         Athens   Attica
# 4  197001000003  1970      1    0               Japan        Fukouka  Fukouka
#
#                         Region                      Attacktype  Weapontype  \
# 0  Central America & Caribbean                   Assassination     Unknown
# 1                North America     Hostage Taking (Kidnapping)     Unknown
# 2               Southeast Asia                   Assassination     Unknown
# 3               Western Europe               Bombing/Explosion  Explosives
# 4                    East Asia  Facility/Infrastructure Attack  Incendiary
#
# ...

# %%
t_data.isnull().sum()
# Out:
# Id               0
# Year             0
# Month            0
# Day              0
# Country          0
# City             0
# State            0
# Region           0
# Attacktype       0
# Weapontype       0
# Targettype       0
# Group            0
# Targetsubtype    0
# Success          0
# Killed           0
# dtype: int64

# %%
t_data.drop_duplicates(inplace=True)

# %%
# Number of total countries
total_countries = t_data['Country'].unique()
print('Their are total {} countries where terror attack happened.'.format(len(total_countries)))
pd.DataFrame(total_countries).rename(columns = {0:'Country'})
# Out:
# Their are total 205 countries where terror attack happened.
#                               Country
# 0                  Dominican Republic
# 1                              Mexico
# 2                         Philippines
# 3                              Greece
# 4                               Japan
# 5                       United States
# 6                             Uruguay
# 7                               Italy
# 8                  East Germany (GDR)
# 9                            Ethiopia
# 10                          Guatemala
# 11                          Venezuela
# 12                 West Germany (FRG)
# 13                        Switzerland
# 14                             Jordan
# 15                              Spain
# 16                             Brazil
# 17                              Egypt
# 18                          Argentina
# 19                            Lebanon
# 20                            Ireland
# 21                             Turkey
# ...

# %%
# Number of total region
t_region = t_data['Region'].unique()
print('Their are total {} region where terror attack happened.'.format(len(t_region)))
pd.DataFrame(t_region).rename(columns = {0:'Region'})
# Out:
# Their are total 12 region where terror attack happened.
#                          Region
# 0   Central America & Caribbean
# 1                 North America
# 2                Southeast Asia
# 3                Western Europe
# 4                     East Asia
# 5                 South America
# 6                Eastern Europe
# 7            Sub-Saharan Africa
# 8    Middle East & North Africa
# 9         Australasia & Oceania
# 10                   South Asia
# 11                 Central Asia

# %%
t_data.drop('Id',axis=1,inplace=True)
t_data.head()
# Out:
#    Year  Month  Day             Country           City    State  \
# 0  1970      7    2  Dominican Republic  Santo Domingo  Unknown
# 1  1970      0    0              Mexico    Mexico city  Federal
# 2  1970      1    0         Philippines        Unknown   Tarlac
# 3  1970      1    0              Greece         Athens   Attica
# 4  1970      1    0               Japan        Fukouka  Fukouka
#
#                         Region                      Attacktype  Weapontype  \
# 0  Central America & Caribbean                   Assassination     Unknown
# 1                North America     Hostage Taking (Kidnapping)     Unknown
# 2               Southeast Asia                   Assassination     Unknown
# 3               Western Europe               Bombing/Explosion  Explosives
# 4                    East Asia  Facility/Infrastructure Attack  Incendiary
#
#                     Targettype                               Group  \
# ...

# %%
t_data.shape
# Out:
# (181691, 14)

# %%
#Most attacked Countries
most_att_countries = t_data['Country'].value_counts().sort_values(ascending=False).head(15)
print('Most attacked country is " {} " with the number of " {} " .'.format(most_att_countries.idxmax(),most_att_countries.max()))
plt.figure(figsize=(15,10))
plt.xticks(rotation=45)
plt.plot(most_att_countries)
# Out:
# Most attacked country is " Iraq " with the number of " 24636 " .

# %%
#Region,in which most attack happened 
most_att_region = t_data['Region'].value_counts().sort_values(ascending=False).head(5)
print('Most of the attacks are happen in the " {} " with the number of " {} " .'.format(most_att_region.idxmax(),most_att_region.max()))
plt.figure(figsize=(15,10))
plt.xticks(rotation=45)
plt.plot(most_att_region)
# Out:
# Most of the attacks are happen in the " Middle East & North Africa " with the number of " 50474 " .

# %%
#Groups,by which most attacks done and top 5 attack groups 
most_att_group = t_data['Group'].value_counts().sort_values(ascending=False).head(5)
print('"{}" did most of the attacks.'.format(most_att_group.index[1]))
most_att_group
# Out:
# "Taliban" did most of the attacks.
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Name: Group, dtype: int64

# %%
#Top 15 states where most of the terrorist activities occur
terror_state =  t_data['State'].value_counts().sort_values(ascending=False).head(15)
print(terror_state)
plt.figure(figsize=(15,10))
plt.xticks(rotation=45)
plt.plot(terror_state)
# Out:
# Baghdad                                7645
# Unknown                                4711
# Northern Ireland                       4498
# Balochistan                            3710
# Saladin                                3411
# Al Anbar                               3299
# Nineveh                                3241
# Sindh                                  3206
# Khyber Pakhtunkhwa                     3084
# Diyala                                 3041
# Lima                                   2615
# Jammu and Kashmir                      2454
# Federally Administered Tribal Areas    2392
# San Salvador                           1923
# Antioquia                              1891
# Name: State, dtype: int64

# %%
#top 15 cities which are most affected by terrorist activities
terror_cities =  t_data['City'].value_counts().sort_values(ascending=False).head(15)
print(terror_cities)
# Out:
# Unknown         10209
# Baghdad          7589
# Karachi          2652
# Lima             2359
# Mosul            2265
# Belfast          2171
# Santiago         1621
# Mogadishu        1581
# San Salvador     1558
# Istanbul         1048
# Athens           1019
# Bogota            984
# Kirkuk            925
# Beirut            918
# Medellin          848
# Name: City, dtype: int64

# %%
#top 6 attack type which are occur most
most_att_type = t_data['Attacktype'].value_counts().sort_values(ascending=False).head(7)
most_att_type
# Out:
# Bombing/Explosion                 88255
# Armed Assault                     42669
# Assassination                     19312
# Hostage Taking (Kidnapping)       11158
# Facility/Infrastructure Attack    10356
# Unknown                            7276
# Unarmed Assault                    1015
# Name: Attacktype, dtype: int64

# %%
#top 15 target type which are targeted most of the time
most_tar_type = t_data['Targettype'].value_counts().sort_values(ascending=False).head(15)
most_tar_type
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Name: Targettype, dtype: int64

# %%
#top 15 sub target type which are targeted most of the time
most_subtar_type = t_data['Targetsubtype'].value_counts().sort_values(ascending=False).head(15)
most_subtar_type
# Out:
# Unnamed Civilian/Unspecified                               11596
# Police Security Forces/Officers                            11178
# Others                                                     10373
# Military Unit/Patrol/Convoy                                 8277
# Military Personnel (soldiers, troops, officers, forces)     7963
# Government Personnel (excluding police, military)           6610
# Village/City/Town/Suburb                                    6542
# Politician or Political Party Movement/Meeting/Rally        6306
# Police Building (headquarters, station, school)             5907
# Military Barracks/Base/Headquarters/Checkpost               5211
# Police Patrol (including vehicles and convoys)              5105
# Government Building/Facility/Office                         4802
# Retail/Grocery/Bakery                                       4274
# Electricity                                                 4198
# ...

# %% [markdown]
# ## Data Visualisation

# %%
plt.figure(figsize=(15,10))
plt.title("Terrorist activities with respect to year")
plt.xticks(rotation = 60)
sns.countplot(t_data.Year)
# Out:
# <AxesSubplot:title={'center':'Terrorist activities with respect to year'}, xlabel='Year', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
plt.title("Terrorist activities with respect to Region and Success")
plt.xticks(rotation = 60)
sns.countplot(t_data.Region,hue = t_data.Success)
# Out:
# <AxesSubplot:title={'center':'Terrorist activities with respect to Region and Success'}, xlabel='Region', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
plt.title("Terrorist activities with respect to month")
sns.countplot(t_data.Month)
# Out:
# <AxesSubplot:title={'center':'Terrorist activities with respect to month'}, xlabel='Month', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
plt.title("Terrorist activities with respect to Attact type")
plt.xticks(rotation = 60)
sns.countplot(t_data.Attacktype)
# Out:
# <AxesSubplot:title={'center':'Terrorist activities with respect to Attact type'}, xlabel='Attacktype', ylabel='count'>

# %%
t_data.Weapontype.replace({'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)':'Vehicles'},inplace=True)

# %%
plt.figure(figsize=(15,10))
plt.title("Terrorist activities with respect to Weapon type")
plt.xticks(rotation = 60)
sns.countplot(t_data.Weapontype)
# Out:
# <AxesSubplot:title={'center':'Terrorist activities with respect to Weapon type'}, xlabel='Weapontype', ylabel='count'>

# %%
plt.figure(figsize=(13,9))
plt.title("Terrorist activities with respect to Targettype type")
sns.countplot(y=t_data.Targettype)
# Out:
# <AxesSubplot:title={'center':'Terrorist activities with respect to Targettype type'}, xlabel='count', ylabel='Targettype'>

# %%
pd.crosstab(t_data.Year,t_data.Region).plot(kind='area',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.heatmap(np.round(t_data.corr(),4),annot=True,cmap='coolwarm')
plt.yticks(rotation=90)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5]),
#  [Text(0, 0.5, 'Year'),
#   Text(0, 1.5, 'Month'),
#   Text(0, 2.5, 'Day'),
#   Text(0, 3.5, 'Success'),
#   Text(0, 4.5, 'Killed')])

# %%
t_data.Success.value_counts().plot(kind='pie',labels=['Success','Fail'],autopct='%1.1f%%',explode=(0.05, 0.15),shadow=True)
plt.ylabel(" ")
# Out:
# Text(0, 0.5, ' ')
